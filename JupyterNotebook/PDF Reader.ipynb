# %%
# Not work proper=====================
# importing required modules
import PyPDF2
# from PyPDF2 import PdfReader

# creating a pdf reader object
reader = PyPDF2.PdfFileReader('/home/jitendra/Downloads/31.pdf')
print(reader)

# printing number of pages in pdf file
page = reader.getNumPages()
print("page", page)

# # get document information
pages = reader.getDocumentInfo()
print(pages)


#
# # get document information
# text = reader.documentInfo
# print("text", text)
# print("get page detail", reader.getPage().getContents())

str = []
print("====",str)

for i in range(page):
    print(i in range(page))
    print(str)
    str += reader.getPage(i).extractText()
#     print(str += reader.getPage(i).extractText())
print("str", str)

# %%
# Extract data from pdf file using plumber its not work in my pc
import requests
import pdfplumber

reader = '/home/jitendra/Downloads/order.pdf'
new = []
with pdfplumber.open(reader) as pdf:
     for page in pdf.pages:
        print(page)
        for line in page.extract_text().splitlines():
            print(line.strip())

#     page = pdf.pages[0]
    
#     text = page.extract_text()
#     new.append(text.split("\n"))
    
# #     for i in new[0]:
# #         if "Order #" in i:
# #             print(i.split("#")[1].strip())
# #         if "Order Date" in i:
# #             print(i.split(":")[1].strip())
# #             break;
        
# print(text)

# %%
for row in text.split('\n'):
    if row.startswith('Order Date'):
       print(row.split()[-1])

# %%
# Convert pdf to image and extract text from image

import pdf2image
from PIL import Image
import pytesseract

image = pdf2image.convert_from_path('/home/jitendra/Downloads/order.pdf')
new = []
for pagenumber, page in enumerate(image):
    detected_text = pytesseract.image_to_string(page)
    #print(detected_text.split("\n"))
    new.append(detected_text.split("\n"))
text = ''
for i in range(len(new)):
    print(range(len(new)))
    text = text + new[i][0] + '\n'
    
print(text)
#     if "Order #" in i:
#         print(i.split("#")[1].strip())
#     if "Order Date" in i:
#         print(i.split(":")[1].strip())
#         break;
# print(detected_text)

# %%
# Current page data is not extract error

import PyPDF2

doc = PyPDF2.PdfFileReader('/home/jitendra/Downloads/order.pdf')
print("Doc", type(doc))

pages = doc.getNumPages()
print("pages", pages)

search = 'Order'

list_pages = []

for i in range(pages):
    current_page = doc.getPage(i)
    text = current_page.extractText()
    print("text======", text)

# %%
# Sale Order Line
# Extract data from pdf file lines using plumber its not work in my pc
# ! pip install pandas

import pdfplumber,re
import pandas as pd

def start_end(data_list):
    start, end = [], []
    for ind, line in enumerate(data_list):
        if 'quantity' in line.lower() and 'description' in line.lower():
            start.append(ind)
#             print("start====", start)
        if 'total' in line.lower():
#             print("End===",ind, line)
            end.append(ind)
#             print("end====", end)
    
    return start, end


def main():
    reader = '/home/jitendra/Downloads/order.pdf'
#     print("reader", reader)
    
    lines = []
#     print("Lines[]",lines)
    
    pdf = pdfplumber.open(reader)
#     print("pdf===", pdf)
    for page in pdf.pages:
        for line in page.extract_text().splitlines():
            if "Order #" in line:
                print("Order Id", line.split("#")[1].strip())
            
            lines.append(re.sub('\s+',' ',line.strip()))
            print("-----",line.strip())
    
    start, end = start_end(lines)
    
    if start == [] or end == []:
#         print("Keyword Not Found!")
        return
    
    start, end = min(start), max(end)
#     print("start---",start, "End===", end)
    
    result ={
        'name': [],
        'product_uom_qty': [],
        'unit_price': [],
        'price_subtotal': [],
        
    }
#     print(result)
    
    for data in lines[start:end]:
#         print(data)
        if 'quantity' not in data.lower() and 'description' not in data.lower():
            print(data)
#             result['name'].append(' '.join(data.split()[0:-5]))
#             result['product_uom_qty'].append(' '.join(data.split()[3:-3]))
#             result['unit_price'].append(data.split()[6])
#             result['price_subtotal'].append(''.join(data.split()[-2:-1]))
#             print("name = ",' '.join(data.split()[0:-5]))
#             print("Total = ",' '.join(data.split()[-2:-1]))
#             print("Unit Price = ",data.split()[6])
#             print("product_uom_qty",' '.join(data.split()[3:-3]))
#     print(result)
#     df = pd.DataFrame(result)
#     print(df)
main()

# %%
# not working ============

# !pip install tabula-py
# !pip install tabulate

from tabula import read_pdf
from tabulate import tabulate

df = read_pdf("/home/jitendra/Downloads/order.pdf", pages="all")


for i in df:
    print(i)

# %%
# blank text ===========

from PyPDF2 import PdfFileReader

reader = PdfFileReader("/home/jitendra/Downloads/order.pdf")
text = ""
for page in reader.pages:
    text += page.extractText() + "\n"

print(text)

# %%
import re
import PyPDF2

# Open the PDF file in binary mode
with open('/home/jitendra/Downloads/order.pdf', 'rb') as pdf_file:
    # Create a PDF reader object
    pdf_reader = PyPDF2.PdfFileReader(pdf_file)
    print("pdf_reader", pdf_reader)

    # Extract text from the first page in the PDF file
    first_page = pdf_reader.getPage(0)
    print("first_page", first_page)
    
    text = first_page.extractText()
    print("text", text)

    # Preprocess the extracted text to remove unnecessary characters and spaces
    text = text.replace('\n', ' ').replace('\r', ' ').replace('\t', ' ')
    print("text", text)

    # Extract the invoice number using regular expressions
    invoice_number_pattern = r'Order # ([A-Z])'
    print("invoice_number_pattern", invoice_number_pattern)
    
    match = re.search(invoice_number_pattern, text)
    print("match", match)
    if match:
        invoice_number = match.group(1)
        print("if partinvoice_number", invoice_number)
    else:
        invoice_number = 'Unknown'
        print("else part invoice_number", invoice_number)
        

    # Extract the total amount using regular expressions
    total_amount_pattern = r'Total ()'
    match = re.search(total_amount_pattern, text)
    if match:
        total_amount = match.group(1)
    else:
        total_amount = 'Unknown'

    # Print the extracted information
    print(f'Invoice number: {invoice_number}')
    print(f'Total amount: {total_amount}')

# %%
# conver pdf file to png file and extract the text
import os
from PIL import Image
import pytesseract
from pdf2image import convert_from_path


pdf_path = "/home/jitendra/Downloads/order.pdf"

# Save PDF pages to images
images = convert_from_path(pdf_path=pdf_path)
for count, img in enumerate(images):
    img_name = f"page_{count}.png"  
    img.save(img_name, "png")

# Extract Text
png_files = [f for f in os.listdir(".") if f.endswith(".png")]
print("png_files===",png_files)

for png_file in png_files:
    print("png_file----", png_file)
    
    extracted_text = pytesseract.image_to_string(Image.open(png_file))
    print(extracted_text)

# %%
# Importing required modules
import PyPDF2
# Creating a pdf file object
pdfFileObj = open('/home/jitendra/Downloads/order.pdf','rb')
# Creating a pdf reader object
pdfReader = PyPDF2.PdfFileReader(pdfFileObj)
# Getting number of pages in pdf file
pages = pdfReader.numPages
# Loop for reading all the Pages
for i in range(pages):
        # Creating a page object
        pageObj = pdfReader.getPage(i)
        # Printing Page Number
        print("Page No: ",i)
        # Extracting text from page
        # And splitting it into chunks of lines
        text = pageObj.extractText().split("  ")
        # Finally the lines are stored into list
        # For iterating over list a loop is used
        for i in range(len(text)):
                # Printing the line
                # Lines are seprated using "\n"
                print(text[i],end="\n\n")
        # For Seprating the Pages
        print()
# closing the pdf file object
pdfFileObj.close()
# Out:
# Page No:  0

# %%
import re
rex = r"\s+(?=\d{2}(?:\d{2})?-\d{1,2}-\d{1,2}\b)"
s = "02/03/2023 11:55:29"
print(re.split(rex, s))

# %%
import re

txt = "12/12/2022 11:15:30"

rex = r"\s+(?=\d{2}(?:\d{2})?-\d{1,2}-\d{1,2}\b)"

print("search", re.search(rex, txt))
print("findall", re.findall(rex, txt))
print("split", re.split(rex, txt))

# %%
# import datetime

# l1 = ['2018-04-16', '2020-04-16', 'ANNOVAR_DATE']

# DATE_FORMAT = "%Y-%m-%d"

# for value in l1:
#     a = datetime.datetime.strptime(value, DATE_FORMAT)        
#     print("a", a)

# %%
# !pip install ocrmypdf

import ocrmypdf
import os
import pdfplumber
import re

pdf_file = "/home/jitendra/Downloads/order.pdf"
# print(pdf_file)

with pdfplumber.open(pdf_file) as pdf:
    for page in pdf.pages:
#         print(page)
        txt = page.extract_text(x_tolerance=2)
#         print(txt)
        
        lines = txt.split('\n')
        print(lines)
        
        amt = re.compile(r'\.\d\d$')
        total = 0
        
        for line in lines:
            if 'Total' in line:
                break
            if amt.search(line):
#                 print(line)
                total += float(line.split()[-1].replace(',', ' ').replace('$', ' ')) 
        print('total', total)
# Out:
# ['Invoicing and Shipping Address: Gemini Furniture', 'Gemini Furniture, Soham Palmer 317 Fairchild Dr', '317 Fairchild Dr Fairfield CA 94535', 'Fairfield CA 94535 United States', 'United States', '\uf095  (379)-167-2040', 'Order # S00007', 'Order Date: Salesperson:', '02/03/2023 11:55:29 Mitchell Admin', 'Description Quantity Unit Price Taxes Amount', '[FURN_6666] Acoustic Bloc Screens 5.00 Units 295.00 1,475.00 €', '[FURN_8999] Three-Seat Sofa 1.00 Units 173.00 173.00 €', 'Three Seater Sofa with Lounger in Steel Grey Colour', '[FURN_8888] Office Lamp 1.00 Units 40.00 40.00 €', '[FURN_7777] Office Chair 1.00 Units 18.00 18.00 €', 'Total 1,706.00 €', 'Page: 1 / 1']
# total 0

# %%
# !pip install wand
# !pip install libmagickwand

# %%
# Error:- PolicyError: attempt to perform an operation not allowed by the security policy `PDF' @ error/constitute.c/IsCoderAuthorized/421

# import io
# from PIL import Image
# import pytesseract
# from wand.image import Image as wi

# pdfFile = wi(filename = '/home/jitendra/Downloads/31.pdf')
# image = pdfFile.convert('jpeg')

# imageBlobs = []

# for img in image.sequence:
#     imgPage = wi(image = img)
#     imageBlobs.append(imgPage.make_blob('jpeg'))

# extract = []

# for imgBlob in imageBlobs:
#     image = Image.open(io.BytesIO(imgBlob))
#     text = pytesseract.image_to_string(image, lang = 'eng')
#     extract.append(text)

# print(extract)

# %%
import pdfplumber
import re

pdf_file = "/home/jitendra/Downloads/order.pdf"
# print(pdf_file)

with pdfplumber.open(pdf_file) as pdf:
    for page in pdf.pages:
        txt = page.extract_text()        
        print(txt)

# %%
for row in txt.split(" "):
#     print(row)
    if row.startswith('date:'):
        date = row.split()[-1].strip("\n")
    if row.startswith('Salesperson:'):
        sp = row.split(":")[-1]
print(date)
print(sp)

# %%
# Conver ocr pdf to image and extract text and conver iage to ocr image

from PIL import Image
import pytesseract
from pdf2image import convert_from_path


pdf_path = "/home/jitendra/Downloads/order.pdf"
print("pdf_path", pdf_path)

for pdf in pdf_path:
    pages = convert_from_path(pdf_path)
    
for pageNum,img in enumerate(pages):
    txt = pytesseract.image_to_string(img, lang='eng')
print(txt.strip())
print(txt.split("\n"))
# Out:
# pdf_path /home/jitendra/Downloads/order.pdf
# ®@ Your logo
#
#
#
# Invoicing and Shipping Address:
# Gemini Furniture, Soham Palmer
# 317 Fairchild Dr
#
# Fairfield CA 94535
#
# United States
#
# & (379)-167-2040
#
# Order # SOO007
#
# Order Date:
# 02/03/2023 11:55:29
#
# Description
# [FURN_6666] Acoustic Bloc Screens
#
# [FURN_8999] Three-Seat Sofa
# Three Seater Sofa with Lounger in Steel Grey Colour
#
#
#
# [FURN_8888] Office Lamp
#
#
#
#
#
#
#
# [FURN_7777] Office Chair
#
# Gemini Furniture
# 317 Fairchild Dr
# Fairfield CA 94535
# United States
#
# Salesperson:
#
#
#
# Mitchell Admin
# Quantity Unit Price Taxes Amount
# 5.00 Units 295.00 1,475.00 €
# 1.00 Units 173.00 173.00 €
# 1.00 Units 40.00 40.00 €
# 1.00 Units 18.00 18.00€
# Total 1,706.00 €
#
#
#
# Page: 1/1
# ...

# %%
for row in txt.split("\n"):
    print(row)
    if "Date:" in row:
        date = row.split()[-1].strip()

    if "invoice" in row:
        order = row.split()[-1].strip()
    
print("====", date)
# print("===", order)
# Out:
# ==== Date:

# %%
# convert pdf file to jpg and create a bounding boxes  
# !pip install opencv
# !pip install pillow

from pdf2image import convert_from_path
import cv2
from PIL import Image


# def main():
#     pdfs = "/home/jitendra/Downloads/order.pdf"
#     pages = convert_from_path(pdfs, 350)
#     print(pages)
    
#     i = 1
#     for page in pages:
#         image_name = "Page_" + str(i) + ".jpg"  
#         img = page.save(image_name, "JPEG")
#         print("img",img)
        
#         i = i+1
#         print(mark_region(img))
#         mark_region(img)
        

# def mark_region(imagE_path):
    
im = cv2.imread("/home/jitendra/Jitendra/Page_1.jpg")

gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
blur = cv2.GaussianBlur(gray, (9,9), 0)
thresh = cv2.adaptiveThreshold(blur,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV,11,30)

# Dilate to combine adjacent text contours
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (9,9))
dilate = cv2.dilate(thresh, kernel, iterations=4)

# Find contours, highlight text areas, and extract ROIs
cnts = cv2.findContours(dilate, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = cnts[0] if len(cnts) == 2 else cnts[1]

line_items_coordinates = []
for c in cnts:
    area = cv2.contourArea(c)
    x,y,w,h = cv2.boundingRect(c)

    if y >= 600 and x <= 1000:
        if area > 10000:
            image = cv2.rectangle(im, (x,y), (2200, y+h), color=(255,0,255), thickness=3)
            line_items_coordinates.append([(x,y), (2200, y+h)])

    if y >= 2400 and x<= 2000:
        image = cv2.rectangle(im, (x,y), (2200, y+h), color=(255,0,255), thickness=3)
        line_items_coordinates.append([(x,y), (2200, y+h)])
print(image)
print(line_items_coordinates)
#     return image, line_items_coordinates
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]
# ...

# %%
#check file extension

import os

filepaths = ["/home/jitendra/Downloads/order.pdf"]

for fp in filepaths:
    # Split the extension from the path and normalise it to lowercase.
    ext = os.path.splitext(fp)[-1].lower()

    # Now we can simply use == to check for equality, no need for wildcards.
    if ext == ".mp3":
        print("is an mp3!")
    elif ext == ".pdf":
        print("is a pdf file!")
    else:
        print("is an unknown file format.")
# Out:
# is a pdf file!

# %%
import PyPDF2

lst_all_text = []
pdf = "/home/jitendra/Downloads/order.pdf"
print(pdf)
for files in pdf
    for file in files:
        # open the pdf file
        object = PyPDF2.PdfFileReader(file))
        print("object", object)
        
        # get number of pages
        NumPages = object.getNumPages()
        print("NumPages", NumPages)
        text =  ""
        
        # extract text and do the search
        for i in range(0, NumPages):         
            PageObj = object.getPage(i)
            text += PageObj.extractText() 
            
        lst_all_text.append(text)

# %%
# import pytesseract
# from pdf2image import convert_from_path

# # images ='/home/jitendra/Jitendra/Page_1.jpg'
# pdfs = "/home/jitendra/Downloads/order.pdf"

# if '.jpg' in str(images):
#     print("image")
#     image_text = pytesseract.image_to_string(images)
#     print(image_text)

# elif '.pdf' in str(pdfs):
#     print("pdf")
#     # for pdf_pat in pdfs:
#     pages = convert_from_path(pdfs)

#     for pageNum, imgBlob in enumerate(pages):
#         text = pytesseract.image_to_string(imgBlob, lang='eng')
#         print(text)
# else:
#     print("File type not match")

# %%
# !pip install PyMuPDF
import fitz

pdf_path = "/home/jitendra/Downloads/order.pdf"

pdf = fitz.open(pdf_path)

pdf.metadata
# Out:
# {'format': 'PDF 1.4',
#  'title': '',
#  'author': '',
#  'subject': '',
#  'keywords': '',
#  'creator': 'wkhtmltopdf 0.12.5',
#  'producer': 'Qt 4.8.7',
#  'creationDate': 'D:20230208104320Z',
#  'modDate': '',
#  'trapped': '',
#  'encryption': None}

# %%
pdf.get_toc()
# Out:
# [[1, 'Order # S00007', 1]]

# %%
pdf.page_count
# Out:
# 1

# %%
num_pages = pdf.page_count
content = []
for i in range(0, num_pages):
    page = pdf.load_page(i)
    page_text = page.get_text()
#     rw_txt = page_text.split("\n")
#     print(rw_txt)
    rw_txt = page_text.replace("\n", " ")
    print(rw_txt)
    
    content.append(rw_txt)
# Out:
# Order # S00007 Description Quantity Unit Price Taxes Amount [FURN_6666] Acoustic Bloc Screens 5.00 Units 295.00 1,475.00 € [FURN_8999] Three-Seat Sofa Three Seater Sofa with Lounger in Steel Grey Colour 1.00 Units 173.00 173.00 € [FURN_8888] Office Lamp 1.00 Units 40.00 40.00 € [FURN_7777] Office Chair 1.00 Units 18.00 18.00 € Invoicing and Shipping Address: Gemini Furniture, Soham Palmer 317 Fairchild Dr Fairfield CA 94535 United States   (379)-167-2040 Gemini Furniture 317 Fairchild Dr Fairfield CA 94535 United States Order Date: 02/03/2023 11:55:29 Salesperson: Mitchell Admin Total 1,706.00 € Page: 1 / 1

# %%
# print(content)
for i in content:
    if "Order #" in i:
        print(i.split("#")[1])
# Out:
#  S00007 Description Quantity Unit Price Taxes Amount [FURN_6666] Acoustic Bloc Screens 5.00 Units 295.00 1,475.00 € [FURN_8999] Three-Seat Sofa Three Seater Sofa with Lounger in Steel Grey Colour 1.00 Units 173.00 173.00 € [FURN_8888] Office Lamp 1.00 Units 40.00 40.00 € [FURN_7777] Office Chair 1.00 Units 18.00 18.00 € Invoicing and Shipping Address: Gemini Furniture, Soham Palmer 317 Fairchild Dr Fairfield CA 94535 United States   (379)-167-2040 Gemini Furniture 317 Fairchild Dr Fairfield CA 94535 United States Order Date: 02/03/2023 11:55:29 Salesperson: Mitchell Admin Total 1,706.00 € Page: 1 / 1

# %%
import requests

url = "https://acord25api.docsumo.com/api/v1/acord25/extract/"

payload = {}
files = [
  ('files', open("/home/jitendra/Downloads/31 (1).pdf",'rb'))
]
print(files)

headers = {
#   'X-API-KEY':'llGJCQH38ZI8gY7hT9Jt6kP0pARb2Oetjmai3ktYp3Y82y7bPljMutUUYsmZ',
}
print(headers)

response = requests.request("POST", url, headers=headers, data = payload, files = files)
print(response)

print(response.json())
# Out:
# [('files', <_io.BufferedReader name='/home/jitendra/Downloads/31 (1).pdf'>)]
# {'X-API-KEY': 'llGJCQH38ZI8gY7hT9Jt6kP0pARb2Oetjmai3ktYp3Y82y7bPljMutUUYsmZ'}
# <Response [400]>
# {'message': '', 'status_code': 400, 'error_code': 'NO_ACORD'}

# %%
import os
import requests

## requests
# path of file
path = '/home/jitendra/Downloads/order.pdf'
filename = os.path.basename(path)
multipart_form_data = {"files": ( filename, open(path, 'rb')),
                        "type": (None, "invoice")}
# headers = {"X-API-KEY": 'llGJCQH38ZI8gY7hT9Jt6kP0pARb2Oetjmai3ktYp3Y82y7bPljMutUUYsmZ'}

r = requests.post(
    "https://app.docsumo.com/api/v1/eevee/apikey/upload/" ,
    files=multipart_form_data,
    headers=headers,
)

r.json()
print(r.json())
print("=================", r)
print("=================")
# Out:
# {'data': {'document': [{'created_at': 'Mon, 20 Feb 2023 06:59:38 GMT', 'doc_id': '6d03c06e6e7c46e68984f6645aaf1d64', 'doc_meta_data': '', 'email': 'jitendra@intechualsolutions.com', 'review_url': 'https://app.docsumo.com/review-document/6d03c06e6e7c46e68984f6645aaf1d64', 'status': 'new', 'title': 'order.pdf', 'type': 'invoice', 'user_doc_id': None, 'user_id': '63f30d161a5a5d923f9c77b3'}]}, 'error': '', 'error_code': '', 'message': '', 'status': 'success', 'status_code': 200}
# ================= <Response [200]>
# ...

# %%
# !pip install pprintpp

import os
import requests
import pprintpp

# The authentication key (API Key).
# Get your own by registering at https://app.pdf.co
# API_KEY = "veroca6890@mustbeit.com_3b2f39470b671e379d59b2733c85db198d6af2443582e28490a1f082c1fb78a6fce67999"

# Base URL for PDF.co Web API requests
BASE_URL = "https://api.pdf.co/v1"
print(BASE_URL)

# Source PDF file
SourceFile = "/home/jitendra/Downloads/order.pdf"
print(SourceFile)


url = "{}/file/upload/get-presigned-url?contenttype=application/octet-stream&name={}".format( BASE_URL, os.path.basename(SourceFile))
print(url)

# Execute request and get response as JSON
# response = requests.get(url, headers={ "x-api-key": 'veroca6890@mustbeit.com_3b2f39470b671e379d59b2733c85db198d6af2443582e28490a1f082c1fb78a6fce67999' })
pprintpp.pprint(response.json())

# print(response.text)
# Out:
# https://api.pdf.co/v1
# /home/jitendra/Downloads/order.pdf
# https://api.pdf.co/v1/file/upload/get-presigned-url?contenttype=application/octet-stream&name=order.pdf
# {
#     'credits': 7,
#     'duration': 0,
#     'error': False,
#     'name': 'order.pdf',
#     'presignedUrl': 'https://pdf-temp-files.s3.us-west-2.amazonaws.com/L1T1T821VNHLDJ2GYFOYTDHW68NC9T9O/order.pdf?X-Amz-Expires=900&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIZJDPLX6D7EHVCKA/20230220/us-west-2/s3/aws4_request&X-Amz-Date=20230220T100722Z&X-Amz-SignedHeaders=content-type;host&X-Amz-Signature=aeacc30b8b8e2e15fb558e60ef1fc6975d1b66bf949914d99b137be6241e1aa7',
#     'remainingCredits': 1353,
#     'status': 200,
# ...

# %%
""" Cloud API asynchronous "PDF To Text" job example.
    Allows to avoid timeout errors when processing huge or scanned PDF documents.
"""
import os
import requests # pip install requests
import time
import datetime

# The authentication key (API Key).
# Get your own by registering at https://app.pdf.co
# API_KEY = "veroca6890@mustbeit.com_3b2f39470b671e379d59b2733c85db198d6af2443582e28490a1f082c1fb78a6fce67999"

# Base URL for PDF.co Web API requests
BASE_URL = "https://api.pdf.co/v1"

# Source PDF file
SourceFile = "/home/jitendra/Downloads/order.pdf"
# Comma-separated list of page indices (or ranges) to process. Leave empty for all pages. Example: '0,2-5,7-'.
Pages = ""
# PDF document password. Leave empty for unprotected documents.
Password = ""
# Destination JSON file name
DestinationFile = "/home/jitendra/Downloads/result.json"
# (!) Make asynchronous job
Async = True


def main(args = None):
    uploadedFileUrl = uploadFile(SourceFile)
    if (uploadedFileUrl != None):
        convertPdfToJson(uploadedFileUrl, DestinationFile)


def convertPdfToJson(uploadedFileUrl, destinationFile):
    """Converts PDF To Json using PDF.co Web API"""

    # Prepare requests params as JSON
    # See documentation: https://apidocs.pdf.co
    parameters = {}
    parameters["async"] = Async
    parameters["name"] = os.path.basename(destinationFile)
    parameters["password"] = Password
    parameters["pages"] = Pages
    parameters["url"] = uploadedFileUrl

    # Prepare URL for 'PDF To Json' API request
    url = "{}/pdf/convert/to/json".format(BASE_URL)

    # Execute request and get response as JSON
    response = requests.post(url, data=parameters, headers={ "x-api-key": API_KEY })
    if (response.status_code == 200):
        json = response.json()

        if json["error"] == False:
            # Asynchronous job ID
            jobId = json["jobId"]
            #  URL of the result file
            resultFileUrl = json["url"]
            
            # Check the job status in a loop. 
            # If you don't want to pause the main thread you can rework the code 
            # to use a separate thread for the status checking and completion.
            while True:
                status = checkJobStatus(jobId) # Possible statuses: "working", "failed", "aborted", "success".
                
                # Display timestamp and status (for demo purposes)
                print(datetime.datetime.now().strftime("%H:%M.%S") + ": " + status)
                
                if status == "success":
                    # Download result file
                    r = requests.get(resultFileUrl, stream=True)
                    if (r.status_code == 200):
                        with open(destinationFile, 'wb') as file:
                            for chunk in r:
                                file.write(chunk)
                        print(f"Result file saved as \"{destinationFile}\" file.")
                    else:
                        print(f"Request error: {response.status_code} {response.reason}")
                    break
                elif status == "working":
                    # Pause for a few seconds
                    time.sleep(3)
                else:
                    print(status)
                    break
        else:
            # Show service reported error
            print(json["message"])
    else:
        print(f"Request error: {response.status_code} {response.reason}")


def checkJobStatus(jobId):
    """Checks server job status"""

    url = f"{BASE_URL}/job/check?jobid={jobId}"
    
    response = requests.get(url, headers={ "x-api-key": API_KEY })
    if (response.status_code == 200):
        json = response.json()
        return json["status"]
    else:
        print(f"Request error: {response.status_code} {response.reason}")

    return None


def uploadFile(fileName):
    """Uploads file to the cloud"""
    
    # 1. RETRIEVE PRESIGNED URL TO UPLOAD FILE.

    # Prepare URL for 'Get Presigned URL' API request
    url = "{}/file/upload/get-presigned-url?contenttype=application/octet-stream&name={}".format(
        BASE_URL, os.path.basename(fileName))
    
    # Execute request and get response as JSON
    response = requests.get(url, headers={ "x-api-key": API_KEY })
    if (response.status_code == 200):
        json = response.json()
        
        if json["error"] == False:
            # URL to use for file upload
            uploadUrl = json["presignedUrl"]
            # URL for future reference
            uploadedFileUrl = json["url"]

            # 2. UPLOAD FILE TO CLOUD.
            with open(fileName, 'rb') as file:
                requests.put(uploadUrl, data=file, headers={ "x-api-key": API_KEY, "content-type": "application/octet-stream" })

            return uploadedFileUrl
        else:
            # Show service reported error
            print(json["message"])    
    else:
        print(f"Request error: {response.status_code} {response.reason}")

    return None


if __name__ == '__main__':
    main()
# Out:
# 16:01.56: success
# Result file saved as "/home/jitendra/Downloads/result.json" file.
