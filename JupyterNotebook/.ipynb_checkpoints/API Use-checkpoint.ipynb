# %% [markdown]
# ## API use

# %%
# !pip install veryfi

import pprintpp
import veryfi

client_id = "vrfDdDSFMvSl6Ng4r3R3bEeLUptTn9nZ4jTDUj8"
client_secret = "pGi2g7lVli3P4xEoVJ01wi7KxfTgOPa6ryluZwJEKrrm8cuAiG5ZzUhe6e0FyKz2r6vYylebpvEMlMJPoYLwGxhdngNYr6CTNdV8V1B4fauJworicikkyUHB2YXALHdu"
username = "veroca6890"
api_key = "16baff73a2eb9b8260b0899e2be176ba"



client = veryfi.Client(client_id, client_secret, username, api_key)

 
result = client.process_document("/home/jitendra/Downloads/order.pdf")
pprintpp.pprint(result)
# Out:
# {
#     'account_number': None,
#     'bill_to': {
#         'address': '317 Fairchild Dr\nFairfield CA 94535',
#         'name': 'Gemini Furniture, Soham Palmer',
#         'parsed_address': None,
#         'vat_number': None,
#     },
#     'cashback': None,
#     'category': 'Job Supplies',
#     'created_date': '2023-02-20 12:57:35',
#     'currency_code': 'EUR',
#     'date': '2023-02-03 11:55:29',
#     'delivery_date': None,
#     'discount': None,
#     'document_reference_number': None,
#     'document_title': None,
#     'document_type': 'purchase_order',
#     'due_date': None,
#     'duplicate_of': None,
#     'external_id': None,
#     'id': 121194632,
#     'img_file_name': '121194632.pdf',
#     'img_thumbnail_url': 'https://scdn.veryfi.com/receipts/2aeebad2e040ac2d/22a05f95-adb6-4eb1-9807-252980f8ac44/thumbnail.jpg?Expires=1676898756&Signature=V88GCEyFMkERsnSSNsFoIp4kg4SivIF-bAchREuNfXTlAaP8NCygDYpqkVtv7C5bHmi~27BTwXGNx91DJAD0jQ-3uEcQq0AgFHTtPngYmQBzWvG5ZnxIsNz7DCJ2phO9U0iEbsjtq4vDA7NWZPdim3WqmAJnHfN6CZnAtOfLQyyPBh8IjMzAmQ94ggNuftOTWAJBHKMfd-P0upgcNLQ0IZE96d-mwvyEUrEybqyQKCA0X~gdd1Y3C0H-WS19VRa5KXcFnQgNoM0nJpHXKMfV6E0mYxfPzvbrfyqE2W19RRYmt6qVk1-SBWEmR1~~pTWkB4pKZpSGSyRmn9gmnbhChA__&Key-Pair-Id=APKAJCILBXEJFZF4DCHQ',
#     'img_url': 'https://scdn.veryfi.com/receipts/2aeebad2e040ac2d/22a05f95-adb6-4eb1-9807-252980f8ac44/4aa68526-71b4-4425-b59b-0c367fcd45ed.pdf?Expires=1676898756&Signature=GK67RlCKHO0bjc03D58I4937FcFq7R2nnOhQzz-GwAiHHbgUNbEWa2NRqXrk-hiWMGg5MBgO7AdfNn9r4xbsKeZ7N~wUlZpwn7U4hsrVB7Ruk5dn5txDNy7AIMK98zyygS1AS9iv~cgXsZxuoF7feq32hfL5eof0xLbd7cgJUsXp1EKvwyEp6iit7kNEuuzZW54NXXcwY4xAZAISly4ISc4LUWzc4K-eKuB1K6rcFoPOfN-lx7hZxCyGyo2yTrlh1UL8Tu4HAbiMuVobSLEkpYdW79Ly2QsJk8SugeUFJr0GrYOy2KPfRFEwvqFqW6peZdrhKTD6RvE86TYoKQJB~g__&Key-Pair-Id=APKAJCILBXEJFZF4DCHQ',
#     'insurance': None,
#     'invoice_number': 'S00007',
#     'is_duplicate': False,
#     'is_money_in': False,
#     'line_items': [
#         {
#             'date': None,
#             'description': 'FURN_6666] Acoustic Bloc Screens\nUnits',
#             'discount': None,
#             'discount_rate': None,
#             'id': 490126394,
#             'order': 0,
#             'price': 295.0,
#             'quantity': 5.0,
#             'reference': None,
#             'section': None,
#             'sku': None,
#             'tags': [],
#             'tax': None,
#             'tax_rate': None,
#             'text': '[FURN_6666] Acoustic Bloc Screens\t\t\t\t5.00 Units\t295.00\t1,475.00 €',
#             'total': 1475.0,
#             'type': 'product',
#             'unit_of_measure': None,
#             'upc': None,
#         },
#         {
#             'date': None,
#             'description': 'FURN_8999] Three-Seat Sofa\nUnits',
#             'discount': None,
#             'discount_rate': None,
#             'id': 490126395,
#             'order': 1,
#             'price': 173.0,
#             'quantity': 1.0,
#             'reference': None,
#             'section': None,
#             'sku': None,
#             'tags': [],
#             'tax': None,
#             'tax_rate': None,
#             'text': '[FURN_8999] Three-Seat Sofa\t\t\t\t1.00 Units\t173.00\t173.00 €',
#             'total': 173.0,
#             'type': 'product',
#             'unit_of_measure': None,
#             'upc': None,
#         },
#         {
#             'date': None,
#             'description': 'Three Seater Sofa with Lounger in Steel Grey Colour',
#             'discount': None,
#             'discount_rate': None,
#             'id': 490126396,
#             'order': 2,
#             'price': None,
#             'quantity': 1.0,
#             'reference': None,
#             'section': None,
#             'sku': None,
#             'tags': [],
#             'tax': None,
#             'tax_rate': None,
#             'text': 'Three Seater Sofa with Lounger in Steel Grey Colour',
#             'total': None,
#             'type': 'product',
#             'unit_of_measure': None,
#             'upc': None,
#         },
#         {
#             'date': None,
#             'description': 'FURN_8888] Office Lamp\nUnits',
#             'discount': None,
#             'discount_rate': None,
#             'id': 490126397,
#             'order': 3,
#             'price': 40.0,
#             'quantity': 1.0,
#             'reference': None,
#             'section': None,
#             'sku': None,
#             'tags': [],
#             'tax': None,
#             'tax_rate': None,
#             'text': '[FURN_8888] Office Lamp\t\t\t\t\t1.00 Units\t40.00\t40.00 €',
#             'total': 40.0,
#             'type': 'product',
#             'unit_of_measure': None,
#             'upc': None,
#         },
#         {
#             'date': None,
#             'description': 'FURN_7777] Office Chair\nUnits',
#             'discount': None,
#             'discount_rate': None,
#             'id': 490126398,
#             'order': 4,
#             'price': 18.0,
#             'quantity': 1.0,
#             'reference': None,
#             'section': None,
#             'sku': None,
#             'tags': [],
#             'tax': None,
#             'tax_rate': None,
#             'text': '[FURN_7777] Office Chair\t\t\t\t\t1.00 Units\t18.00\t18.00 €',
#             'total': 18.0,
#             'type': 'product',
#             'unit_of_measure': None,
#             'upc': None,
#         },
#     ],
#     'meta': {'owner': 'veroca6890'},
#     'notes': None,
#     'ocr_text': 'to Your logo\n\nInvoicing and Shipping Address:\t\t\t\tGemini Furniture\nGemini Furniture, Soham Palmer\t\t\t\t317 Fairchild Dr\n317 Fairchild Dr\t\t\t\t\t\tFairfield CA 94535\nFairfield CA 94535\t\t\t\t\t\tUnited States\nUnited States\n\uf095\t(379)-167-2040\nOrder # S00007\nOrder Date:\t\t\t\t\tSalesperson:\n02/03/2023 11:55:29\t\t\t\tMitchell Admin\nDescription\t\t\t\t\t\tQuantity\tUnit Price\tTaxes\tAmount\n[FURN_6666] Acoustic Bloc Screens\t\t\t\t5.00 Units\t295.00\t1,475.00 €\n[FURN_8999] Three-Seat Sofa\t\t\t\t1.00 Units\t173.00\t173.00 €\nThree Seater Sofa with Lounger in Steel Grey Colour\n[FURN_8888] Office Lamp\t\t\t\t\t1.00 Units\t40.00\t40.00 €\n[FURN_7777] Office Chair\t\t\t\t\t1.00 Units\t18.00\t18.00 €\n\n\tTotal\t\t\t\t1,706.00 €\n\n\tPage: 1/1',
#     'order_date': None,
#     'payment': {
#         'card_number': '0007',
#         'display_name': 'Visa ***0007',
#         'terms': None,
#         'type': 'visa',
#     },
#     'pdf_url': 'https://scdn.veryfi.com/receipts/2aeebad2e040ac2d/22a05f95-adb6-4eb1-9807-252980f8ac44/4aa68526-71b4-4425-b59b-0c367fcd45ed.pdf?Expires=1676898757&Signature=VdaF6LeC9tlGV11c4bFH5Ou3G9ZUdn0S4A6pqnII95Wtq0pIasOL8GaquIxO2ndGHsJk6h4~BJaOuY97j1Ll7YSS1BmnbaQGK8WAEs62t87uteGWrVO5hKMCy9oY1kWuN2I0HhaUCWgqVAcQXyPduyp3gj1l8j9ojp6gITmZrD34oEXpYi~pdapatinJzSiUUrpDbA~~m2qi8NmojEKp6PNuDUm9NGoBx~VUoEBdDv7uhxs-JjQSmCBBt5ABoWLcFQesQ4fzjvwz-z~EtCQD6wsgZuQAMilFRXI6Wg7G0Ywmi7pyh6fWMiemcOzhvsRzBJxKqYEfjncm8D8GRm2ETw__&Key-Pair-Id=APKAJCILBXEJFZF4DCHQ',
#     'purchase_order_number': None,
#     'reference_number': 'VBADB-94632',
#     'rounding': None,
#     'service_end_date': None,
#     'service_start_date': None,
#     'ship_date': None,
#     'ship_to': {
#         'address': '317 Fairchild Dr\nFairfield CA 94535',
#         'name': 'Gemini Furniture',
#         'parsed_address': None,
#     },
#     'shipping': None,
#     'store_number': None,
#     'subtotal': 1706.0,
#     'tags': [],
#     'tax': None,
#     'tax_lines': [],
#     'tip': None,
#     'total': 1706.0,
#     'total_weight': None,
#     'tracking_number': None,
#     'updated_date': '2023-02-20 12:57:37',
#     'vendor': {
#         'abn_number': None,
#         'account_number': None,
#         'address': None,
#         'bank_name': None,
#         'bank_number': None,
#         'bank_swift': None,
#         'category': 'Furniture Store',
#         'email': None,
#         'fax_number': None,
#         'iban': None,
#         'lat': None,
#         'lng': None,
#         'logo': None,
#         'name': None,
#         'phone_number': '(379)-167-2040',
#         'raw_address': None,
#         'raw_name': None,
#         'reg_number': None,
#         'type': 'Furniture Store',
#         'vat_number': None,
#         'web': None,
#     },
# }
